# %% [markdown]
# <a href="https://colab.research.google.com/github/Shivaram17/AccEngine_PythonDemoCodes/blob/main/10002TodictIndex.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# importing pandas module
import pandas as pd

# reading csv file from url
data = pd.read_csv("https://media.geeksforgeeks.org/wp-content/uploads/nba.csv")

# dropping null value columns to avoid errors
data.dropna(inplace = True)

# converting to dict
data_dict = data.to_dict(orient = 'index')

# display
data_dict
# Out:
# {0: {'Age': 25.0,
#   'College': 'Texas',
#   'Height': '6-2',
#   'Name': 'Avery Bradley',
#   'Number': 0.0,
#   'Position': 'PG',
#   'Salary': 7730337.0,
#   'Team': 'Boston Celtics',
#   'Weight': 180.0},
#  1: {'Age': 25.0,
#   'College': 'Marquette',
#   'Height': '6-6',
#   'Name': 'Jae Crowder',
#   'Number': 99.0,
#   'Position': 'SF',
#   'Salary': 6796117.0,
#   'Team': 'Boston Celtics',
#   'Weight': 235.0},
#  3: {'Age': 22.0,
#   'College': 'Georgia State',
#   'Height': '6-5',
#   'Name': 'R.J. Hunter',
#   'Number': 28.0,
#   'Position': 'SG',
#   'Salary': 1148640.0,
#   'Team': 'Boston Celtics',
#   'Weight': 185.0},
#  6: {'Age': 21.0,
#   'College': 'LSU',
#   'Height': '6-8',
#   'Name': 'Jordan Mickey',
#   'Number': 55.0,
#   'Position': 'PF',
#   'Salary': 1170960.0,
#   'Team': 'Boston Celtics',
#   'Weight': 235.0},
#  7: {'Age': 25.0,
#   'College': 'Gonzaga',
#   'Height': '7-0',
#   'Name': 'Kelly Olynyk',
#   'Number': 41.0,
#   'Position': 'C',
# ...
